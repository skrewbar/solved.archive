# %% [markdown]
# # [최댓값](https://www.acmicpc.net/problem/2562)

# %%
max_, maxIndex = 0, 0

for i in range(1, 10):
    n = int(input())

    if max_ < n:
        max_ = n
        maxIndex = i

print(max_)
print(maxIndex)
